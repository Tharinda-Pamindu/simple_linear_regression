# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.9.0

# %%
sklearn.show_versions()
# Out:
# System:
#     python: 3.14.7 (tags/v3.14.7:823f032, Aug  5 2026, 10:51:32) [MSC v.1944 64 bit (AMD64)]
# executable: D:\Tharinda\CAME\DAY 12\Practical\venv\Scripts\python.exe
#    machine: Windows-11-10.0.26200-SP0
#
# Python dependencies:
#       sklearn: 1.9.0
#           pip: 26.2.1
#    setuptools: None
#         numpy: 2.5.2
#         scipy: 1.18.1
#        Cython: None
#        pandas: None
#    matplotlib: None
#        joblib: 1.5.3
# threadpoolctl: 3.6.0
#      narwhals: 2.25.0
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        user_api: openmp
#    internal_api: openmp
#     num_threads: 8
#          prefix: vcomp
#        filepath: D:\Tharinda\CAME\DAY 12\Practical\venv\Lib\site-packages\sklearn\.libs\vcomp140.dll
#         version: None
#
#        user_api: blas
#    internal_api: openblas
#     num_threads: 8
#          prefix: libscipy_openblas
# ...
